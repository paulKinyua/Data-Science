# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/HP/Downloads/sales_data_sample.csv", encoding='latin')

df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
condition = (df['STATUS'] == "Shipped")

condition.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: STATUS, dtype: bool

# %%
df[df['ORDERNUMBER'] >= 10373].head(3)
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 22        10375               21      34.91               12   733.11
# 23        10388               42      76.36                4  3207.12
# 24        10403               24     100.00                7  2434.56
#
#         ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 22  2/3/2005 0:00  Shipped       1         2     2005  ...
# 23  3/3/2005 0:00  Shipped       1         3     2005  ...
# 24  4/8/2005 0:00  Shipped       2         4     2005  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2         CITY STATE POSTALCODE  \
# 22  67, rue des Cinquante Otages           NaN       Nantes   NaN      44000
# 23             1785 First Street           NaN  New Bedford    MA      50553
# 24  Berkeley Gardens 12  Brewery           NaN    Liverpool   NaN    WX1 6LT
#
#    COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 22  France      EMEA         Labrune           Janine    Small
# ...
