# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
# import chardet

# %%
# make a function that cleans the data

def cleanColumn(data):
    #get all the key values
    keysList = list(data.keys())
    
    #loop through the key values
    for key in keysList:
        #replace the uppercase key values with lowercase values
        data[key.lower()] = data.pop(key)
        
    #remove the white spaces
    data = { x.translate({32:None}) : y 
                 for x, y in data.items()}
    return data

# %%
df = pd.read_csv("C:/Users/HP/Downloads/sales_data_sample.csv", encoding='latin')

df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# get info on loaded data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
#get rows and columns
df.shape
# Out:
# (2823, 25)

# %%
#create a new temp dataset
temp = df._append(df)
temp
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
#drop duplicates, use inplace=True to strictly check the duplicates
temp.drop_duplicates(inplace=True)
temp.shape

# Another important argument for drop_duplicates() is keep, which has three possible options:

# first: (default) Drop duplicates except for the first occurrence.
# last: Drop duplicates except for the last occurrence.
# False: Drop all duplicates.

# temp_df.drop_duplicates(inplace=True, keep=False)
# Out:
# (2823, 25)

# %%
#print out the column names
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
# turn all column names to lower case
df.columns = [col.lower() for col in df]

df.columns

temp.columns = [col.lower() for col in temp]

temp.columns
# Out:
# Index(['ordernumber', 'quantityordered', 'priceeach', 'orderlinenumber',
#        'sales', 'orderdate', 'status', 'qtr_id', 'month_id', 'year_id',
#        'productline', 'msrp', 'productcode', 'customername', 'phone',
#        'addressline1', 'addressline2', 'city', 'state', 'postalcode',
#        'country', 'territory', 'contactlastname', 'contactfirstname',
#        'dealsize'],
#       dtype='object')

# %%
#count number of null values in each coldf.isnull().sum()
df.isnull().sum()
# Out:
# ordernumber            0
# quantityordered        0
# priceeach              0
# orderlinenumber        0
# sales                  0
# orderdate              0
# status                 0
# qtr_id                 0
# month_id               0
# year_id                0
# productline            0
# msrp                   0
# productcode            0
# customername           0
# phone                  0
# addressline1           0
# addressline2        2521
# city                   0
# state               1486
# postalcode            76
# country                0
# territory           1074
# contactlastname        0
# contactfirstname       0
# dealsize               0
# dtype: int64

# %%
# dropping null values
temp.dropna()
# temp.isnull().sum()

#you can specify what column you want to be removed by adding axis=1
# temp.dropna(axis=1)
temp.isnull().sum()
# Out:
# ordernumber            0
# quantityordered        0
# priceeach              0
# orderlinenumber        0
# sales                  0
# orderdate              0
# status                 0
# qtr_id                 0
# month_id               0
# year_id                0
# productline            0
# msrp                   0
# productcode            0
# customername           0
# phone                  0
# addressline1           0
# addressline2        2521
# city                   0
# state               1486
# postalcode            76
# country                0
# territory           1074
# contactlastname        0
# contactfirstname       0
# dealsize               0
# dtype: int64

# %%
#using imputation to replace null values, start by creating a new variable
addressLine2 = temp['addressline2']
addressLine2.head()

addressLine2_mean = addressLine2.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 5
#       2 addressLine2 = temp['addressline2']
#       3 addressLine2.head()
# ----> 5 addressLine2_mean = addressLine2.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# ...

# %%
addressLine2.fillna(revenue_mean, inplace=True)
